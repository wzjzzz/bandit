# %%
from bandit_e import BMO_E

# %%
T = 60000
init_x = [0,0]
init_cube_length = 1
eta = 1e-4
epsilon = 1e-2
delta = 1e-3
c = 2.5


regrets_all = []
regrets_delta_all = []
for _ in range(10):
    A = BMO_E(T, init_x, init_cube_length, eta, epsilon, delta, c)
    regrets_delta, regrets = A.plot()
    regrets_all.append(regrets)
    regrets_delta_all.append(regrets_delta)
# Out:
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------
# ------initialize--------
# get f_delta:
# ----play batch 0 ------
# 100.0
# Hb 19.66305217250066
# every cube need to be played 100 times this batch
# have play 400 times totally
# ----play batch 1 ------
# 144.0
# Hb 16.385876810417216
# every cube need to be played 144 times this batch
# have play 875 times totally
# ----play batch 2 ------
# 225.0
# Hb 13.108701448333772
# every cube need to be played 225 times this batch
# have play 1631 times totally
# ----play batch 3 ------
# 441.0
# Hb 9.363358177381267
# every cube need to be played 441 times this batch
# have play 3170 times totally
# ----play batch 4 ------
# 1156.0
# Hb 5.783250638970782
# every cube need to be played 1156 times this batch
# have play 7353 times totally
# ----play batch 5 ------
# 7744.0
# Hb 2.234437746875075
# every cube need to be played 7744 times this batch
# have play 37173 times totally
# ----play batch 6 ------
# 25600.0
# Hb 1.2289407607812912
# every cube need to be played 25600 times this batch
# have play 60000 times totally
# ----play batch 7 ------

# %%
import matplotlib.pyplot as plt
import numpy as np
for i in range(10):
    plt.plot(np.cumsum(regrets_all, axis=1)[i], label='{}'.format(i))
plt.legend()
plt.show()

for i in range(10):
    plt.plot(np.cumsum(regrets_delta_all, axis=1)[i], label='{}'.format(i))
plt.legend()
plt.show()

# %%
regret_m = np.mean(np.cumsum(regrets_all, axis=1), axis=0)
regret_std = np.std(np.cumsum(regrets_all, axis=1), axis=0)
regret_m_delta = np.mean(np.cumsum(regrets_delta_all, axis=1), axis=0)
regret_std_delta = np.std(np.cumsum(regrets_delta_all, axis=1), axis=0)

# %%
import matplotlib.pyplot as plt
plt.plot(regret_m)
plt.plot(regret_m_delta)
plt.fill_between(np.array(range(len(regret_m))), 
                 regret_m - regret_std, regret_m + regret_std, alpha=0.1, color='b')
plt.fill_between(np.array(range(len(regret_m_delta))), 
                                regret_m_delta - regret_std_delta, regret_m_delta + regret_std_delta, alpha=0.1, color='r')
plt.show()

# %%
import numpy as np
np.savetxt('bmo_eli_delta.csv', regrets_delta_all)
np.savetxt('bmo_eli.csv', regrets_all)
